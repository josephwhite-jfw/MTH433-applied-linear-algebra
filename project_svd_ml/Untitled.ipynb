# %%
import numpy as np
import pandas as pd

df = pd.read_csv(r"C:\Repositories\mth-433-applied-linear-algebra\project_svd_ml\433pitch.csv")

def matrix_prep(A):
    """
    """
    # Standardize (Demean)
    mu = np.mean(A, axis=0)
    A  = A - mu

    # Normalize
    A /= np.linalg.norm(A, axis=0)
    return A

# %%
def pc_var(A,k):
