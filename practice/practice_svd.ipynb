# %%
import numpy as np

# %%
# 8.5.1 Finding Eigenvalues and Orthonormal Eigenvector Bases
# (a)
# (b)
B = np.array([[-2,3],
             [3,6]
             ])

lam = np.linalg.eigh(B)
lam
# Out:
# EighResult(eigenvalues=array([-3.,  7.]), eigenvectors=array([[-0.9486833 ,  0.31622777],
#        [ 0.31622777,  0.9486833 ]]))
